# %% [markdown]
# # Linear Discriminant Analysis

# %% [markdown]
# ## Import Modules and Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/sanja/Downloads/Breast_Cancer.csv")
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %% [markdown]
# # Splitting the Feature and Target

# %%
x = df.iloc[:, :-1]
y = df.iloc[:,  -1]
x.shape, y.shape
# Out:
# ((569, 30), (569,))

# %% [markdown]
# ## Splitting the Feature and Target into Train and Test

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2)
xtrain.shape, xtest.shape, ytrain.shape, ytest.shape
# Out:
# ((455, 30), (114, 30), (455,), (114,))

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis(n_components=1)
xtrain_lda = lda.fit_transform(xtrain, ytrain)
#xtest_lda = lda.transform(xtest)
xtrain_lda.shape, xtest_lda.shape, xlda.shape
# Out:
# ((455, 1), (114, 1), (569, 1))

# %%
lda.explained_variance_ratio_
# Out:
# array([1.])

# %%
xtrain_lda
# Out:
# array([[-0.19478933],
#        [-1.52301425],
#        [ 2.58454807],
#        [ 3.72139508],
#        [ 1.42753664],
#        [ 1.89060475],
#        [ 3.89660417],
#        [-1.26694633],
#        [-2.41483603],
#        [-0.88563135],
#        [-1.76112232],
#        [-0.69497978],
#        [-0.80469255],
#        [-1.20328419],
#        [-1.63524394],
#        [ 3.39708059],
#        [-0.7393769 ],
#        [-0.87421864],
#        [-0.32600108],
#        [-1.14563589],
#        [ 3.08791873],
#        [-1.38521815],
#        [ 2.47329678],
#        [-2.1590348 ],
#        [ 1.12645594],
#        [-1.30606898],
#        [-0.50639288],
#        [-1.92523248],
#        [ 2.08393778],
#        [ 3.33820873],
#        [ 2.62017371],
#        [-0.28708362],
#        [-2.01559734],
#        [ 4.43862001],
#        [ 2.1864205 ],
#        [-0.79647784],
#        [-1.13425184],
#        [-1.20987278],
#        [-0.56674798],
#        [-1.50110273],
#        [-1.23861253],
# ...

# %% [markdown]
# ## Predict the test result and validate the score

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y, lda.predict(x))
# Out:
# 0.9666080843585237

# %%
#Dont Consider
plt.scatter(xtrain_lda[:,0][ytrain ==0], xtrain_lda[:,0][ytrain ==0], label = "class 1")
plt.scatter(xtrain_lda[:,0][ytrain ==1], xtrain_lda[:,0][ytrain ==1], label = "class 2")

# %% [markdown]
# ## LDA - Multiclass

# %%
db = pd.read_csv("C:/Users/sanja/Downloads/DryBeanDataset/DryBeanDataset/Dry_Bean_Dataset.csv")
db
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
db.Class.nunique(), db.Class.unique()
# Out:
# (7,
#  array(['SEKER', 'BARBUNYA', 'BOMBAY', 'CALI', 'HOROZ', 'SIRA', 'DERMASON'],
#        dtype=object))

# %%
d = {'SEKER': 0, 'BARBUNYA': 1, 'BOMBAY': 2, 'CALI' :3, 'HOROZ': 4, 'SIRA': 5, 'DERMASON': 6}
db.Class = db.Class.map(d)
db
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %% [markdown]
# # Splitting the Feature and Target

# %%
x = db.iloc[:, :-1]
y = db.iloc[:, -1]
x.shape, y.shape
# Out:
# ((13611, 16), (13611,))

# %% [markdown]
# ## Splitting the Feature and Target into Train and Test

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# ## Fitting into the Model

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis(n_components=6)
xtrainlda = lda.fit_transform(xtrain, ytrain)
xtestlda = lda.transform(xtest)
pd.DataFrame(xtrainlda)
# Out:
#               0         1         2         3         4         5
# 0     -4.044984  1.945505  0.249280 -2.214816 -2.496673  0.468526
# 1      0.808351  2.540103 -1.096827  1.294812 -0.471563 -0.804017
# 2      2.187038 -0.757214 -1.410758 -0.538675 -0.428246 -1.483331
# 3      2.384477 -1.447002 -0.861705 -0.501220 -0.312005 -1.090880
# 4      2.746914 -1.609013 -2.200806 -0.178239  0.250933 -0.367159
# ...         ...       ...       ...       ...       ...       ...
# 10883 -1.479577  2.243063  0.331991 -1.808992 -0.681193 -0.541081
# 10884  0.357153  4.922264 -0.518529  3.173463  0.157164 -0.641896
# 10885  2.808903 -2.102217 -1.595730 -0.119652  0.307530  0.191825
# 10886  2.697735 -2.962901 -3.570570 -0.165443  0.451625  2.537791
# 10887  2.093365 -2.202660 -3.404542 -0.397993  1.053287  2.645131
#
# [10888 rows x 6 columns]

# %%
Classes = ['SEKER', 'BARBUNYA', 'BOMBAY', 'CALI', 'HOROZ', 'SIRA', 'DERMASON']
xlda = lda.transform(x)
ypred = lda.predict(x)
for i in range (db.Class.nunique()):
    plt.scatter(xlda[:,0][ypred==i], xlda[:,1][ypred==i], label = Classes[i])
plt.legend()

# %% [markdown]
# ## Predict the test result and validate the score

# %%
ypred = lda.predict(xtest)
accuracy_score(ytest, ypred)
# Out:
# 0.9052971860994784

# %%
xlda = lda.transform(x)
xlda
# Out:
# array([[ 2.64560397, -2.29568022,  2.3349111 ,  2.56688456, -1.10262122,
#          2.36632129],
#        [ 1.29270789, -1.00920455,  3.786095  ,  1.54295031, -1.84028842,
#          0.97411574],
#        [ 2.66513143, -2.23925345,  2.51120935,  2.38796371, -0.82322466,
#          2.00287574],
#        ...,
#        [ 2.12363902, -1.26741527, -0.55920229, -0.59546598, -0.26807195,
#         -1.29814969],
#        [ 2.01923924, -1.03692788, -0.84948366, -0.69393082, -0.23857321,
#         -1.41105911],
#        [ 1.76999401, -0.14500354, -1.24767758, -0.6713666 , -0.14509348,
#         -1.22413173]])
